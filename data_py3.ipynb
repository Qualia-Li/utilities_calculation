# %%
from lib import *

xu_chen = Tenant("Xu Chen", start=datetime(2019, 1, 1), end=datetime(2019, 12, 16))
zewei_chen = Tenant("Zewei Chen", start=datetime(2019, 1, 1))
quanlai_li = Tenant("Quanlai Li", start=datetime(2019, 9, 1), end=datetime(2019, 12, 8))
ping_hu = Tenant("Ping Hu", start=datetime(2019, 5, 10), end=datetime(2019, 8, 25))

Bill(start=datetime(2019, 6, 17), end=datetime(2019, 8, 15), name="Water 2019-06-17 ~ 2019-08-15")\
    .charge_per_usage(184.5, [xu_chen, zewei_chen, quanlai_li, ping_hu])

Bill(start=datetime(2019, 7, 1), end=datetime(2019, 7, 31), name="Internet 2019-07")\
    .charge_per_day(0.5, [xu_chen, zewei_chen, ping_hu])
Bill(start=datetime(2019, 8, 1), end=datetime(2019, 8, 31), name="Internet 2019-08")\
    .charge_per_day(0.5, [xu_chen, zewei_chen, ping_hu])
Bill(start=datetime(2019, 9, 1), end=datetime(2019, 9, 30), name="Internet 2019-09")\
    .charge_per_day(0.5, [xu_chen, zewei_chen, quanlai_li])

Bill(start=datetime(2019, 9, 1), end=datetime(2019, 9, 30), name="Cleaning 2019-09")\
    .charge_per_day(0.33, [xu_chen, zewei_chen, quanlai_li])

Bill(start=datetime(2019, 8, 2), end=datetime(2019, 9 ,3), name="PGE 2019-08-02 ~ 2019-09-03")\
    .charge_per_usage(108.88, [xu_chen, zewei_chen, quanlai_li, ping_hu])
Bill(start=datetime(2019, 7, 3), end=datetime(2019, 8, 1), name="PGE 2019-07-03 ~ 2019-08-01")\
    .charge_per_usage(81.14, [xu_chen, zewei_chen, ping_hu])


quanlai_li.check()
xu_chen.check()
zewei_chen.check()
ping_hu.check()
# Out:
# --------------------
# Quanlai Li
# Internet 2019-09
# 	Billing Period: 2019-09-01 ~ 2019-09-30
# 	Actual Period: 2019-09-01 ~ 2019-09-30
# 	0.50*30=		15.00
# Cleaning 2019-09
# 	Billing Period: 2019-09-01 ~ 2019-09-30
# 	Actual Period: 2019-09-01 ~ 2019-09-30
# 	0.33*30=		9.90
# PGE 2019-08-02 ~ 2019-09-03
# 	Billing Period: 2019-08-02 ~ 2019-09-03
# 	Actual Period: 2019-09-01 ~ 2019-09-03
# 	108.88/93*3=		3.51
# Due:		28.41
# --------------------
# --------------------
# Xu Chen
# Water 2019-06-17 ~ 2019-08-15
# 	Billing Period: 2019-06-17 ~ 2019-08-15
# 	Actual Period: 2019-06-17 ~ 2019-08-15
# 	184.50/180*60=		61.50
# Internet 2019-07
# 	Billing Period: 2019-07-01 ~ 2019-07-31
# 	Actual Period: 2019-07-01 ~ 2019-07-31
# 	0.50*31=		15.50
# Internet 2019-08
# 	Billing Period: 2019-08-01 ~ 2019-08-31
# 	Actual Period: 2019-08-01 ~ 2019-08-31
# 	0.50*31=		15.50
# Internet 2019-09
# 	Billing Period: 2019-09-01 ~ 2019-09-30
# 	Actual Period: 2019-09-01 ~ 2019-09-30
# 	0.50*30=		15.00
# Cleaning 2019-09
# 	Billing Period: 2019-09-01 ~ 2019-09-30
# 	Actual Period: 2019-09-01 ~ 2019-09-30
# 	0.33*30=		9.90
# PGE 2019-08-02 ~ 2019-09-03
# 	Billing Period: 2019-08-02 ~ 2019-09-03
# 	Actual Period: 2019-08-02 ~ 2019-09-03
# 	108.88/93*33=		38.63
# PGE 2019-07-03 ~ 2019-08-01
# 	Billing Period: 2019-07-03 ~ 2019-08-01
# 	Actual Period: 2019-07-03 ~ 2019-08-01
# 	81.14/90*30=		27.05
# Due:		183.08
# --------------------
# --------------------
# Zewei Chen
# Water 2019-06-17 ~ 2019-08-15
# 	Billing Period: 2019-06-17 ~ 2019-08-15
# 	Actual Period: 2019-06-17 ~ 2019-08-15
# 	184.50/180*60=		61.50
# Internet 2019-07
# 	Billing Period: 2019-07-01 ~ 2019-07-31
# 	Actual Period: 2019-07-01 ~ 2019-07-31
# 	0.50*31=		15.50
# Internet 2019-08
# 	Billing Period: 2019-08-01 ~ 2019-08-31
# 	Actual Period: 2019-08-01 ~ 2019-08-31
# 	0.50*31=		15.50
# Internet 2019-09
# 	Billing Period: 2019-09-01 ~ 2019-09-30
# 	Actual Period: 2019-09-01 ~ 2019-09-30
# 	0.50*30=		15.00
# Cleaning 2019-09
# 	Billing Period: 2019-09-01 ~ 2019-09-30
# 	Actual Period: 2019-09-01 ~ 2019-09-30
# 	0.33*30=		9.90
# PGE 2019-08-02 ~ 2019-09-03
# 	Billing Period: 2019-08-02 ~ 2019-09-03
# 	Actual Period: 2019-08-02 ~ 2019-09-03
# 	108.88/93*33=		38.63
# PGE 2019-07-03 ~ 2019-08-01
# 	Billing Period: 2019-07-03 ~ 2019-08-01
# 	Actual Period: 2019-07-03 ~ 2019-08-01
# 	81.14/90*30=		27.05
# Due:		183.08
# --------------------
# --------------------
# Ping Hu
# Water 2019-06-17 ~ 2019-08-15
# 	Billing Period: 2019-06-17 ~ 2019-08-15
# 	Actual Period: 2019-06-17 ~ 2019-08-15
# 	184.50/180*60=		61.50
# Internet 2019-07
# 	Billing Period: 2019-07-01 ~ 2019-07-31
# 	Actual Period: 2019-07-01 ~ 2019-07-31
# 	0.50*31=		15.50
# Internet 2019-08
# 	Billing Period: 2019-08-01 ~ 2019-08-31
# 	Actual Period: 2019-08-01 ~ 2019-08-25
# 	0.50*25=		12.50
# PGE 2019-08-02 ~ 2019-09-03
# 	Billing Period: 2019-08-02 ~ 2019-09-03
# 	Actual Period: 2019-08-02 ~ 2019-08-25
# 	108.88/93*24=		28.10
# PGE 2019-07-03 ~ 2019-08-01
# 	Billing Period: 2019-07-03 ~ 2019-08-01
# 	Actual Period: 2019-07-03 ~ 2019-08-01
# 	81.14/90*30=		27.05
# Due:		144.64
# --------------------

# %%
yuchen_guo = Tenant("Yuchen Guo", start=datetime(2019, 10, 21), end=datetime(2020, 2, 14))

Bill(start=datetime(2019, 10, 1), end=datetime(2019, 12, 10), name="Internet")\
    .charge_per_day(0.5)

Bill(start=datetime(2019, 10, 1), end=datetime(2019, 12, 10), name="Cleaning")\
    .charge_per_day(0.33)

Bill(start=datetime(2019, 9, 4), end=datetime(2019, 10 ,1), name="PGE")\
    .charge_per_usage(48.33)
Bill(start=datetime(2019, 10, 2), end=datetime(2019, 10, 30), name="PGE")\
    .charge_per_usage(73.01)

Bill(start=datetime(2019, 8, 15), end=datetime(2019, 10, 15), name="Water")\
    .charge_per_usage(184.51)

quanlai_li.check()
xu_chen.check()
zewei_chen.check()
ping_hu.check()
yuchen_guo.check()
# Out:
# --------------------
# Quanlai Li
# Internet
# 	Billing Period: 2019-10-01 ~ 2019-12-10
# 	Actual Period: 2019-10-01 ~ 2019-12-08
# 	0.50*69=		34.50
# Cleaning
# 	Billing Period: 2019-10-01 ~ 2019-12-10
# 	Actual Period: 2019-10-01 ~ 2019-12-08
# 	0.33*69=		22.77
# PGE
# 	Billing Period: 2019-09-04 ~ 2019-10-01
# 	Actual Period: 2019-09-04 ~ 2019-10-01
# 	48.33/84*28=		16.11
# PGE
# 	Billing Period: 2019-10-02 ~ 2019-10-30
# 	Actual Period: 2019-10-02 ~ 2019-10-30
# 	73.01/97*29=		21.83
# Water
# 	Billing Period: 2019-08-15 ~ 2019-10-15
# 	Actual Period: 2019-09-01 ~ 2019-10-15
# 	184.51/180*45=		46.13
# Due:		141.34
# --------------------
# --------------------
# Xu Chen
# Internet
# 	Billing Period: 2019-10-01 ~ 2019-12-10
# 	Actual Period: 2019-10-01 ~ 2019-12-10
# 	0.50*71=		35.50
# Cleaning
# 	Billing Period: 2019-10-01 ~ 2019-12-10
# 	Actual Period: 2019-10-01 ~ 2019-12-10
# 	0.33*71=		23.43
# PGE
# 	Billing Period: 2019-09-04 ~ 2019-10-01
# 	Actual Period: 2019-09-04 ~ 2019-10-01
# 	48.33/84*28=		16.11
# PGE
# 	Billing Period: 2019-10-02 ~ 2019-10-30
# 	Actual Period: 2019-10-02 ~ 2019-10-30
# 	73.01/97*29=		21.83
# Water
# 	Billing Period: 2019-08-15 ~ 2019-10-15
# 	Actual Period: 2019-08-15 ~ 2019-10-15
# 	184.51/180*62=		63.55
# Due:		160.42
# --------------------
# --------------------
# Zewei Chen
# Internet
# 	Billing Period: 2019-10-01 ~ 2019-12-10
# 	Actual Period: 2019-10-01 ~ 2019-12-10
# 	0.50*71=		35.50
# Cleaning
# 	Billing Period: 2019-10-01 ~ 2019-12-10
# 	Actual Period: 2019-10-01 ~ 2019-12-10
# 	0.33*71=		23.43
# PGE
# 	Billing Period: 2019-09-04 ~ 2019-10-01
# 	Actual Period: 2019-09-04 ~ 2019-10-01
# 	48.33/84*28=		16.11
# PGE
# 	Billing Period: 2019-10-02 ~ 2019-10-30
# 	Actual Period: 2019-10-02 ~ 2019-10-30
# 	73.01/97*29=		21.83
# Water
# 	Billing Period: 2019-08-15 ~ 2019-10-15
# 	Actual Period: 2019-08-15 ~ 2019-10-15
# 	184.51/180*62=		63.55
# Due:		160.42
# --------------------
# --------------------
# Ping Hu
# Water
# 	Billing Period: 2019-08-15 ~ 2019-10-15
# 	Actual Period: 2019-08-15 ~ 2019-08-25
# 	184.51/180*11=		11.28
# Due:		11.28
# --------------------
# --------------------
# Yuchen Guo
# Internet
# 	Billing Period: 2019-10-01 ~ 2019-12-10
# 	Actual Period: 2019-10-21 ~ 2019-12-10
# 	0.50*51=		25.50
# Cleaning
# 	Billing Period: 2019-10-01 ~ 2019-12-10
# 	Actual Period: 2019-10-21 ~ 2019-12-10
# 	0.33*51=		16.83
# PGE
# 	Billing Period: 2019-10-02 ~ 2019-10-30
# 	Actual Period: 2019-10-21 ~ 2019-10-30
# 	73.01/97*10=		7.53
# Due:		49.86
# --------------------

# %%
yuqing_sun = Tenant("Yuqing Sun", start=datetime(2020, 1, 11))

Bill(start=datetime(2019, 12, 11), end=datetime(2020, 3, 10), name="Internet")\
    .charge_per_day(0.5)

Bill(start=datetime(2019, 10, 15), end=datetime(2019, 12, 18), name="Water")\
    .charge_per_usage(196.28)
Bill(start=datetime(2019, 12, 18), end=datetime(2019, 2, 20), name="Water")\
    .charge_per_usage(142.35)

Bill(start=datetime(2019, 11, 1), end=datetime(2019, 12, 3), name="PGE")\
    .charge_per_usage(57.39)
Bill(start=datetime(2019, 12, 4), end=datetime(2020, 1, 2), name="PGE")\
    .charge_per_usage(103.08)
Bill(start=datetime(2020, 1, 3), end=datetime(2020, 1, 31), name="PGE")\
    .charge_per_usage(91.81)

zewei_chen.check()
xu_chen.check()
quanlai_li.check()
yuchen_guo.check()
yuqing_sun.check()
# Out:
# --------------------
# Zewei Chen
# Internet
# 	Billing Period: 2019-12-11 ~ 2020-03-10
# 	Actual Period: 2019-12-11 ~ 2020-03-10
# 	0.50*91=		45.50
# Water
# 	Billing Period: 2019-10-15 ~ 2019-12-18
# 	Actual Period: 2019-10-15 ~ 2019-12-18
# 	196.28/242*65=		52.72
# PGE
# 	Billing Period: 2019-11-01 ~ 2019-12-03
# 	Actual Period: 2019-11-01 ~ 2019-12-03
# 	57.39/132*33=		14.35
# PGE
# 	Billing Period: 2019-12-04 ~ 2020-01-02
# 	Actual Period: 2019-12-04 ~ 2020-01-02
# 	103.08/78*30=		39.65
# PGE
# 	Billing Period: 2020-01-03 ~ 2020-01-31
# 	Actual Period: 2020-01-03 ~ 2020-01-31
# 	91.81/79*29=		33.70
# Due:		185.92
# --------------------
# --------------------
# Xu Chen
# Internet
# 	Billing Period: 2019-12-11 ~ 2020-03-10
# 	Actual Period: 2019-12-11 ~ 2019-12-16
# 	0.50*6=		3.00
# Water
# 	Billing Period: 2019-10-15 ~ 2019-12-18
# 	Actual Period: 2019-10-15 ~ 2019-12-16
# 	196.28/242*63=		51.10
# PGE
# 	Billing Period: 2019-11-01 ~ 2019-12-03
# 	Actual Period: 2019-11-01 ~ 2019-12-03
# 	57.39/132*33=		14.35
# PGE
# 	Billing Period: 2019-12-04 ~ 2020-01-02
# 	Actual Period: 2019-12-04 ~ 2019-12-16
# 	103.08/78*13=		17.18
# Due:		85.63
# --------------------
# --------------------
# Quanlai Li
# Water
# 	Billing Period: 2019-10-15 ~ 2019-12-18
# 	Actual Period: 2019-10-15 ~ 2019-12-08
# 	196.28/242*55=		44.61
# PGE
# 	Billing Period: 2019-11-01 ~ 2019-12-03
# 	Actual Period: 2019-11-01 ~ 2019-12-03
# 	57.39/132*33=		14.35
# PGE
# 	Billing Period: 2019-12-04 ~ 2020-01-02
# 	Actual Period: 2019-12-04 ~ 2019-12-08
# 	103.08/78*5=		6.61
# Due:		65.56
# --------------------
# --------------------
# Yuchen Guo
# Internet
# 	Billing Period: 2019-12-11 ~ 2020-03-10
# 	Actual Period: 2019-12-11 ~ 2020-02-14
# 	0.50*66=		33.00
# Water
# 	Billing Period: 2019-10-15 ~ 2019-12-18
# 	Actual Period: 2019-10-21 ~ 2019-12-18
# 	196.28/242*59=		47.85
# PGE
# 	Billing Period: 2019-11-01 ~ 2019-12-03
# 	Actual Period: 2019-11-01 ~ 2019-12-03
# 	57.39/132*33=		14.35
# PGE
# 	Billing Period: 2019-12-04 ~ 2020-01-02
# 	Actual Period: 2019-12-04 ~ 2020-01-02
# 	103.08/78*30=		39.65
# PGE
# 	Billing Period: 2020-01-03 ~ 2020-01-31
# 	Actual Period: 2020-01-03 ~ 2020-01-31
# 	91.81/79*29=		33.70
# Due:		168.55
# --------------------
# --------------------
# Yuqing Sun
# Internet
# 	Billing Period: 2019-12-11 ~ 2020-03-10
# 	Actual Period: 2020-01-11 ~ 2020-03-10
# 	0.50*60=		30.00
# PGE
# 	Billing Period: 2020-01-03 ~ 2020-01-31
# 	Actual Period: 2020-01-11 ~ 2020-01-31
# 	91.81/79*21=		24.41
# Due:		54.41
# --------------------

# %%
chen_benhao = Tenant('Chen Benhao', start=datetime(2020, 3, 16), end=datetime(2020, 4, 4))


Bill(start=datetime(2020, 3, 11), end=datetime(2020, 6, 3), name="Internet")\
    .charge_per_day(0.5)

Bill(start=datetime(2020, 2, 20), end=datetime(2020, 4, 16), name="Water")\
    .charge_per_usage(184.43)

Bill(start=datetime(2020, 2, 1), end=datetime(2020, 3, 1), name="PGE")\
    .charge_per_usage(75.53)
Bill(start=datetime(2020, 3, 1), end=datetime(2020, 4, 1), name="PGE")\
    .charge_per_usage(49.58)
Bill(start=datetime(2020, 4, 1), end=datetime(2020, 5, 1), name="PGE")\
    .charge_per_usage(61.67)

# %%
zewei_chen.check()
chen_benhao.check()
yuqing_sun.check()
# Out:
# --------------------
# Zewei Chen
# Internet
# 	Billing Period: 2020-03-11 ~ 2020-06-03
# 	Actual Period: 2020-03-11 ~ 2020-06-03
# 	0.50*85=		42.50
# Water
# 	Billing Period: 2020-02-20 ~ 2020-04-16
# 	Actual Period: 2020-02-20 ~ 2020-04-16
# 	184.43/134*57=		78.45
# PGE
# 	Billing Period: 2020-02-01 ~ 2020-03-01
# 	Actual Period: 2020-02-01 ~ 2020-03-01
# 	75.53/74*30=		30.62
# PGE
# 	Billing Period: 2020-03-01 ~ 2020-04-01
# 	Actual Period: 2020-03-01 ~ 2020-04-01
# 	49.58/81*32=		19.59
# PGE
# 	Billing Period: 2020-04-01 ~ 2020-05-01
# 	Actual Period: 2020-04-01 ~ 2020-05-01
# 	61.67/66*31=		28.97
# Due:		200.13
# --------------------
# --------------------
# Chen Benhao
# Internet
# 	Billing Period: 2020-03-11 ~ 2020-06-03
# 	Actual Period: 2020-03-16 ~ 2020-04-04
# 	0.50*20=		10.00
# Water
# 	Billing Period: 2020-02-20 ~ 2020-04-16
# 	Actual Period: 2020-03-16 ~ 2020-04-04
# 	184.43/134*20=		27.53
# PGE
# 	Billing Period: 2020-03-01 ~ 2020-04-01
# 	Actual Period: 2020-03-16 ~ 2020-04-01
# 	49.58/81*17=		10.41
# PGE
# 	Billing Period: 2020-04-01 ~ 2020-05-01
# 	Actual Period: 2020-04-01 ~ 2020-04-04
# 	61.67/66*4=		3.74
# Due:		51.67
# --------------------
# --------------------
# Yuqing Sun
# Internet
# 	Billing Period: 2020-03-11 ~ 2020-06-03
# 	Actual Period: 2020-03-11 ~ 2020-06-03
# 	0.50*85=		42.50
# Water
# 	Billing Period: 2020-02-20 ~ 2020-04-16
# 	Actual Period: 2020-02-20 ~ 2020-04-16
# 	184.43/134*57=		78.45
# PGE
# 	Billing Period: 2020-02-01 ~ 2020-03-01
# 	Actual Period: 2020-02-01 ~ 2020-03-01
# 	75.53/74*30=		30.62
# PGE
# 	Billing Period: 2020-03-01 ~ 2020-04-01
# 	Actual Period: 2020-03-01 ~ 2020-04-01
# 	49.58/81*32=		19.59
# PGE
# 	Billing Period: 2020-04-01 ~ 2020-05-01
# 	Actual Period: 2020-04-01 ~ 2020-05-01
# 	61.67/66*31=		28.97
# Due:		200.13
# --------------------
